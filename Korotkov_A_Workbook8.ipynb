# %% [markdown]
# Дан массив данных
# 𝑋 = 𝑛𝑝. 𝑎𝑟𝑟𝑎𝑦([[5,3],
# [10,15],
# [15,12],
# [24,10],
# [30,45],
# [85,70],
# [71,80],
# [60,78],
# [55,52],
# [80,91], ])
# Требуется провести кластерный анализ данных методом k-средних.
# Поэкспериментируйте с количеством кластеров.

# %%
import sns
from matplotlib import pyplot as plt
from sklearn.svm._libsvm import predict
from sklearn.cluster import KMeans
import numpy as np

x = np.array([[5,3],
               [10,15],
               [15,12],
               [24,10],
               [30,45],
               [85,70],
               [71,80],
               [60,78],
               [55,52],
               [80,91], ])
kmeans = KMeans (n_clusters = 3)
kmeans. fit(x)
y_kmeans = kmeans.predict(x)
plt.scatter(x[:, 0], x[:, 1], c = y_kmeans, s = 20)
centers = kmeans. cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c = 'blue', s = 100, alpha = 0.9);
plt.show()

# %% [markdown]
# Выполните кластеризацию для набора данных ирисов Фишера. Выполните
# предсказания для модели. Поэкспериментируйте с количеством кластеров.

# %%
from sklearn.datasets import load_iris
import seaborn as sns
from sklearn.cluster import KMeans
iris = load_iris()
X = iris.data
y = iris.target
n_clusters_list = [2, 3, 4]

# Создание графика
fig, axs = plt.subplots(1, len(n_clusters_list), figsize=(15, 5))

for i, n_clusters in enumerate(n_clusters_list):
    # Создание и обучение модели KMeans
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(X)

    # Получение меток кластеров
    labels = kmeans.labels_

    # Визуализация результатов
    axs[i].scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
    axs[i].scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='x', c='r', s=100)
    axs[i].set_title(f'{n_clusters} кластера')
    axs[i].set_xlabel(iris.feature_names[0])
    axs[i].set_ylabel(iris.feature_names[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# Задание. Выполните иерархическую кластеризацию для набора данных об
# ирисах Фишера. При этом необходимо использовать любые два признака
# (всего их четыре).

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# Загрузка данных
iris = load_iris()
X = iris.data[:, :2]  # Используем только первые два признака (длина и ширина чашелистика)

# Иерархическая кластеризация
agg_clustering = AgglomerativeClustering(n_clusters=3)  # Указываем количество кластеров
agg_clustering.fit(X)

# Визуализация результатов
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=agg_clustering.labels_, cmap='viridis')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Hierarchical Clustering of Iris Dataset')
plt.colorbar(label='Cluster')
plt.show()
